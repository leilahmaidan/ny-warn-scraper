# %%
# use the import keyword to import pandas, requests, and bs4 modules
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# assign the NY WARN notice url to a variable
url = "https://labor.ny.gov/app/warn/default.asp"

# %%
# define headers
headers = {'accept-encoding': 'deflate', 'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36'}

# %%
# make a get request to the url using the requests library and assign the response to a variable called 'response'
response = requests.get(url, headers=headers)

# %%
# print out status code of response to confirm that your request worked
response.status_code
# Out:
# 200

# %%
# parse the response text using Beautiful Soup's html parser and assign output to a variable called 'soup'
# response.text
type(response.text)
# Out:
# str

# %%
# scrape the first table on the page and assign it to a variable called 'table'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# get the dropdown menu
select = soup.find("select", id="warnYr")
select
# Out:
# <select id="warnYr" name="warnYr" onchange="pageRefresh()">
# <option selected="" value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# </select>

# %%
years = select.find_all("option")
years
# Out:
# [<option selected="" value="2020">2020</option>,
#  <option value="2019">2019</option>,
#  <option value="2018">2018</option>,
#  <option value="2017">2017</option>,
#  <option value="2016">2016</option>,
#  <option value="2015">2015</option>,
#  <option value="2014">2014</option>,
#  <option value="2013">2013</option>,
#  <option value="2012">2012</option>]

# %%
years = [option.text for option in select.find_all("option")]
years
# Out:
# ['2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012']

# %%
# make an array called 'results'
results = []
control_numbers = set()
#loop through all years
for year in years:
    # form url for a specific year, eg https://labor.ny.gov/app/warn/default.asp?warnYr=2019
    year_url = f'https://labor.ny.gov/app/warn/default.asp?warnYr={year}'
    print(year_url)
    # make get request to url
    response = requests.get(year_url, headers=headers)
    # scrape the first table on the page and assign it to a variable called 'table'
    soup = BeautifulSoup(response.text, 'html.parser')

    table = soup.find("table")

    # get all the rows in the table — this is how many WARN notices there were in a specific year
    rows = table.find_all("tr")
    print(len(rows))

    # grab all rows from the table and assign to a variable called 'rows'
    # loop through the rows using a for loop. each row here is a company
    for row in rows:
        # grab the anchor tag (the link tag) in the row and then grab the href attribute from the tag
        a = row.find("a")['href']

        # concatenate the root url from above with this href attribute and assign to a variable called 'company_url'
        company_url = "https://labor.ny.gov/app/warn/"+a
        print(company_url)

        # make a get request to the company url assign the response to a variable called 'company_response'
        company_response = requests.get(company_url, headers=headers)

        # parse the response text and assign output to a variable called 'company_soup'
        company_soup = BeautifulSoup(company_response.text, 'html.parser')

        # grab the first table on the page
        company_table = company_soup.find("table")

        # loop through all of the p tags
        paragraphs = company_table.find_all("p")
        paragraphs_iter = iter(paragraphs)
        skip = False
        for p in paragraphs_iter:
            # grab all of the values we want
            text = p.get_text('\n').replace('\xa0', '')
            if 'Date of Notice:' in text:
                notice_date = text.split(":")[1].strip().split('\n')[0].strip().replace(',', '').replace(';', '')
            elif 'Control Number:' in text:
                control_number = text.split(":")[1].strip()
                if control_number in control_numbers:
                    print('repeated control number')
                    skip = True
                    break
                else:
                    control_numbers.add(control_number)
            elif 'Reason Stated for Filing:' in text:
                reason = text.split(":")[1].strip()
                #print(reason)
            elif 'Company:' in text:
                split_company = [x.strip() for x in text.split('\n')]
                if len(split_company) == 1:
                    next_text = next(paragraphs_iter)
                else: 
                    company = split_company[1]
                    address = ' '.join(split_company[2:])
            elif 'County:' in text:
                county = f'{text.split(":")[1].strip().split("|")[0].strip()} County'
                #print(county)
            elif 'Phone:' in text:
                phone = text.split(":")[1].strip()
                #print(phone)
            elif 'Business Type:' in text:
                business_type = text.split(":")[1].strip().replace('Restaurants', 'Restaurant')
                #print(business_type)
            elif 'Number Affected:' in text:
                if '-----' in text:
                    affected = ''
                else:
                    affected = text.split(":")[1].strip().split(" ")[0].strip().split('\n')[0].strip()
                #print(affected)
            elif 'Total Employees:' in text:
                if '-----' in text:
                    total_employees = ''
                else:
                    total_employees = text.split(":")[1].strip().split(" ")[0].strip().replace(',', '')
                    #print(total_employees)
            elif 'Layoff Date:' in text:
                #print(text)
                layoff_date = text.split(":")[1].strip().split(" ")[0].strip().split(" ")[0].strip()
                #print(layoff_date)
            elif ('Reason for Dislocation:' in text):
                dislocation = text.split(":")[1].strip()
                #print(dislocation)
            elif ('Union:' in text):
                union = text.split(":")[1].strip()
                #print(union)
            elif ('Classification:' in text):
                classification = text.split(":")[1].strip()
                #print(classification)

        # store values in a result object
        if not skip:
            result = {
                'notice_date': notice_date,
                'reason': reason,
                'company': company,
                'address': address,
                'county': county,
                'phone': phone,
                'business_type': business_type,
                'affected': affected,
                'total_employees': total_employees,
                'layoff_date': layoff_date,
                'dislocation': dislocation,
                'union': union,
                'classification': classification
             }
            # append result object to results
            results.append(result)

print(len(results))
# Out:
# https://labor.ny.gov/app/warn/default.asp?warnYr=2020
# 1430
# https://labor.ny.gov/app/warn/details.asp?id=8480
# https://labor.ny.gov/app/warn/details.asp?id=8481
# https://labor.ny.gov/app/warn/details.asp?id=8482
# https://labor.ny.gov/app/warn/details.asp?id=8483
# https://labor.ny.gov/app/warn/details.asp?id=8484
# https://labor.ny.gov/app/warn/details.asp?id=8485
# https://labor.ny.gov/app/warn/details.asp?id=8486
# https://labor.ny.gov/app/warn/details.asp?id=8487
# https://labor.ny.gov/app/warn/details.asp?id=8488
# https://labor.ny.gov/app/warn/details.asp?id=8489
# https://labor.ny.gov/app/warn/details.asp?id=8490
# https://labor.ny.gov/app/warn/details.asp?id=8491
# https://labor.ny.gov/app/warn/details.asp?id=8492
# https://labor.ny.gov/app/warn/details.asp?id=8493
# https://labor.ny.gov/app/warn/details.asp?id=8494
# https://labor.ny.gov/app/warn/details.asp?id=8467
# https://labor.ny.gov/app/warn/details.asp?id=8468
# https://labor.ny.gov/app/warn/details.asp?id=8469
# https://labor.ny.gov/app/warn/details.asp?id=8470
# https://labor.ny.gov/app/warn/details.asp?id=8471
# https://labor.ny.gov/app/warn/details.asp?id=8472
# https://labor.ny.gov/app/warn/details.asp?id=8473
# https://labor.ny.gov/app/warn/details.asp?id=8474
# https://labor.ny.gov/app/warn/details.asp?id=8475
# https://labor.ny.gov/app/warn/details.asp?id=8476
# https://labor.ny.gov/app/warn/details.asp?id=8477
# https://labor.ny.gov/app/warn/details.asp?id=8478
# https://labor.ny.gov/app/warn/details.asp?id=8479
# https://labor.ny.gov/app/warn/details.asp?id=8461

#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant layoff'},
#  {'notice_date': '10/16/2019',
#   'reason': 'Plant Closing',
#   'company': 'Barneys New York',
#   'address': '575 5th Avenue New York, NY 10017',
#   'county': 'New York County',
#   'phone': '(212) 450-8606',
#   'business_type': 'Retail',
#   'affected': '165',
#   'total_employees': '165',
#   'layoff_date': 'Employment',
#   'dislocation': 'Economic',
#   'union': 'New York New Jersey Regional Joint Board Workers United A/W SEIU',
#   'classification': 'Plant Closing'},
#  {'notice_date': '9/18/2019',
#   'reason': 'Plant Closing',
#   'company': 'General Parts Distribution, LLC d/b/a Carquest Auto Parts',
#   'address': '215 Business Park Drive Armonk, NY 10504',
#   'county': 'Westchester County',
#   'phone': '(860) 375-1514',
#   'business_type': 'Auto parts distribution',
#   'affected': '80',
#   'total_employees': '80',
#   'layoff_date': 'Of',
#   'dislocation': 'Economic',
#   'union': 'Teamsters Local 202',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/7/2019',
#   'reason': 'Plant Closing',
#   'company': 'Somos Healthcare Providers, Inc.',
#   'address': '519 Eighth Avenue, 14th Floor New York, NY 10118',
#   'county': 'New York County',
#   'phone': '(516) 642-4068',
#   'business_type': 'Community care and advocate community provider',
#   'affected': '130',
#   'total_employees': '130',
#   'layoff_date': 'Separations',
#   'dislocation': 'New York State contract expired',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/20/2019',
#   'reason': 'Plant Unit Closing',
#   'company': 'Regeneron Healthcare Solutions, Inc., a wholly owned subsidiary of Regeneron Pharmaceuticals, Inc.',
#   'address': '1 Rockwood Rd. Sleepy Hollow, NY 10591',
#   'county': 'Westchester County',
#   'phone': '(914) 847-7128',
#   'business_type': 'Biotechnology company',
#   'affected': '15',
#   'total_employees': '',
#   'layoff_date': '2/18/2020',
#   'dislocation': 'Termination of all field and supporting staff associated with one of their products.',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Unit Closing'},
#  {'notice_date': '12/12/2019',
#   'reason': 'Plant Closing',
#   'company': 'Spacious Technologies LLC subsidiary of WeWork Companies, LLC',
#   'address': '134 Fifth Avenue New York, NY 10011',
#   'county': 'New York County',
#   'phone': '(646) 809-4474',
#   'business_type': 'Commercial real estate company',
#   'affected': '48',
#   'total_employees': '48',
#   'layoff_date': 'March',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/22/2019(Amended',
#   'reason': 'Plant Layoff',
#   'company': 'WeWork Companies, Inc.',
#   'address': '115 W 18th St. New York, NY 10011',
#   'county': 'New York County',
#   'phone': '(646) 809-4474',
#   'business_type': 'Commercial real estate company',
#   'affected': '423',
#   'total_employees': '922',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '12/17/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Eastman Kodak Company (Eastman Business Park)',
#   'address': '1669 Lake Avenue Rochester, NY 14650',
#   'county': 'Monroe County',
#   'phone': '(585) 724-6615',
#   'business_type': 'Photographic equipment and Supplies',
#   'affected': '3',
#   'total_employees': '',
#   'layoff_date': 'March',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '12/10/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Eastman Kodak Company (Kodak Office)',
#   'address': '343 State Street Rochester, NY 14650',
#   'county': 'Monroe County',
#   'phone': '(585) 724-6615',
#   'business_type': 'Photographic equipment and Supplies',
#   'affected': '1',
#   'total_employees': '178',
#   'layoff_date': 'March',
#   'dislocation': 'Economic',
#   'union': 'The employee is not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '12/12/2019',
#   'reason': 'Plant Closing',
#   'company': 'Eyeview, Inc.',
#   'address': '33 East 33rd Street, 6th Floor New York, NY 10016',
#   'county': 'New York County',
#   'phone': '(646) 714-1855',
#   'business_type': 'Video marketing technology company',
#   'affected': '61',
#   'total_employees': '61',
#   'layoff_date': '12/31/2019',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/12/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Evolent Health LLC',
#   'address': '519 8th Ave, Suite 14 New York, NY 10018',
#   'county': 'New York County',
#   'phone': '(571) 386-1990',
#   'business_type': 'a company providing an integrated value-based care platform for the nations leading providers and payers',
#   'affected': '49',
#   'total_employees': '',
#   'layoff_date': 'March',
#   'dislocation': 'Loss of contract with SOMOS Healthcare Providers. Inc.',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '12/10/2019',
#   'reason': 'Plant Layoff',
#   'company': 'HCL America, Inc.',
#   'address': '800 Phillips Road Webster, NY 14580',
#   'county': 'Monroe County',
#   'phone': '(908) 731-2256',
#   'business_type': 'Leading global IT services company',
#   'affected': '16',
#   'total_employees': '217',
#   'layoff_date': 'March',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '11/19/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Eastman Kodak Company (Kodak Office)',
#   'address': '343 State Street Rochester, NY 14650',
#   'county': 'Monroe County',
#   'phone': '(585) 724-6615',
#   'business_type': 'Photographic equipment and Supplies',
#   'affected': '1',
#   'total_employees': '',
#   'layoff_date': 'February',
#   'dislocation': 'Economic',
#   'union': 'The remote employee is not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '9/30/2019',
#   'reason': 'Plant Closing',
#   'company': 'PB&J Group, LLC (dba Candle 79)',
#   'address': '154 East 79th Street New York, NY 10075',
#   'county': 'New York County',
#   'phone': '(718) 679-5214',
#   'business_type': 'Organic restaurant',
#   'affected': '48',
#   'total_employees': '48',
#   'layoff_date': '12/31/2019',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/9/2019',
#   'reason': 'Plant Layoff',
#   'company': 'GBG USA Inc. (Global Brands Group)',
#   'address': 'Corporate Headquarters 350 5th Ave New York, NY 10118',
#   'county': 'New York County',
#   'phone': '(646) 839-7614',
#   'business_type': 'Apparel store offices',
#   'affected': '83',
#   'total_employees': '340',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '9/9/2019',
#   'reason': 'Plant Closing',
#   'company': 'Catholic Guardian Services',
#   'address': '140 Casals Place, Co-Op City, Apt. 21 H Bronx, NY 10475',
#   'county': 'Bronx County',
#   'phone': '(212) 371-1000 Ext',
#   'business_type': 'Human services non-profit organization with programs that help a large needy population in the New York metropolitan area.',
#   'affected': '34',
#   'total_employees': '174',
#   'layoff_date': 'The',
#   'dislocation': 'Discontinuation of operations',
#   'union': 'United Food & Commercial Workers’ Union (UFCW) Local 888',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/11/2019',
#   'reason': 'Plant Closing',
#   'company': 'Castelli America, LLC',
#   'address': '5151, 5152, 5183 Fairbanks Road and 5185 Route 474, Harmony, New York 14710 (also known as 5185 Route 474, Ashville, New York 14710)',
#   'county': 'Chautauqua County',
#   'phone': '(716) 782-2101',
#   'business_type': 'Cheese manufacturer',
#   'affected': '68',
#   'total_employees': '68',
#   'layoff_date': 'December',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/6/2019',
#   'reason': 'Plant Closing',
#   'company': 'Gibsons Bar and Steakhouse (at the Polo Bar Ralph Lauren)',
#   'address': '1 E. 55th Street New York, NY 10022',
#   'county': 'New York County',
#   'phone': '(312) 587-0575 Ext',
#   'business_type': 'Restaurant',
#   'affected': '156',
#   'total_employees': '156',
#   'layoff_date': 'Separations',
#   'dislocation': 'Gibsons Bar and Steakhouse is ceasing its operations at the Polo Bar Ralph Lauren.',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/5/2019',
#   'reason': 'Plant Closing',
#   'company': 'Brooks-TLC Hospital System, Inc., TLC Health Network Campus',
#   'address': '845 Routes 5 & 20 (Main Road) Irving, NY 14081',
#   'county': 'Chautauqua County',
#   'phone': '(716) 363-7263',
#   'business_type': 'Acute Care Hospital',
#   'affected': '201',
#   'total_employees': '201',
#   'layoff_date': 'December',
#   'dislocation': 'Economic',
#   'union': '1199 SEIU United Healthcare Workers East',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/4/2019',
#   'reason': 'Plant Closing',
#   'company': 'GL&V USA, Inc. (Part of Valmet)',
#   'address': '27 Allen Street Hudson Falls, NY 12839',
#   'county': 'Washington County',
#   'phone': '(518) 747-1367',
#   'business_type': 'Paper mill machinery manufacturer',
#   'affected': '40',
#   'total_employees': '40',
#   'layoff_date': 'Layoffs',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/27/2019',
#   'reason': 'Plant Layoff',
#   'company': 'HCL America, Inc.',
#   'address': '800 Phillips Road Webster, NY 14580',
#   'county': 'Monroe County',
#   'phone': '(908) 731-2256',
#   'business_type': 'Leading global IT services company',
#   'affected': '11',
#   'total_employees': '',
#   'layoff_date': '1/16/2020',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '11/22/2019',
#   'reason': 'Plant Layoff',
#   'company': 'WeWork Companies, Inc.',
#   'address': '115 W 18th St. New York, NY 10011',
#   'county': 'New York County',
#   'phone': '(646) 809-4474',
#   'business_type': 'Commercial real estate company',
#   'affected': '414',
#   'total_employees': '911',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '12/6/2019',
#   'reason': 'Plant Closing',
#   'company': 'Crystal Run Health Plan, LLC (Phase 3)',
#   'address': '109 Rykowski Lane Middletown, NY 10941',
#   'county': 'Orange County',
#   'phone': '(845) 703-6106',
#   'business_type': 'Health Plans',
#   'affected': '4',
#   'total_employees': '18',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/5/2019',
#   'reason': 'Plant Closing',
#   'company': 'Quality Frozen Foods, Inc.',
#   'address': '1663 62nd Street Brooklyn, NY 11204',
#   'county': 'Brooklyn County',
#   'phone': '(718) 256-9100',
#   'business_type': 'Wholesale grocer',
#   'affected': '82',
#   'total_employees': '82',
#   'layoff_date': 'Separations',
#   'dislocation': 'Sale of the business',
#   'union': 'Teamsters Local 707',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/3/2019',
#   'reason': 'Plant Layoff',
#   'company': 'KIK Custom Products',
#   'address': '935 East Hiawatha Blvd. Syracuse, NY 13208',
#   'county': 'Onondaga County',
#   'phone': '(337) 421-6011',
#   'business_type': 'Packaging and labeling services',
#   'affected': '27',
#   'total_employees': '38',
#   'layoff_date': 'The',
#   'dislocation': 'Significant reduction in production',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '12/3/2019',
#   'reason': 'Plant Closing',
#   'company': 'Icahn Capital L.P.',
#   'address': '767 Fifth Avenue New York, NY 10153',
#   'county': 'New York County',
#   'phone': '(212) 702-4354',
#   'business_type': 'Private equity',
#   'affected': '3',
#   'total_employees': '27',
#   'layoff_date': 'March',
#   'dislocation': 'Relocating to Miami, Florida',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/2/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Featherstone Foods, Inc.',
#   'address': '1164 E. 156th Street Bronx, NY 10474',
#   'county': 'Bronx County',
#   'phone': '(914) 497-2204',
#   'business_type': 'Food products supplier',
#   'affected': '99',
#   'total_employees': '99',
#   'layoff_date': 'March',
#   'dislocation': 'Acquisition of Featherstone Foods, Inc. by Featherstone Distribution, LLC.',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '11/27/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Crosstex International, Inc. (Cantel) Phase 3',
#   'address': '10 Ranick Road Hauppauge, NY 11788',
#   'county': 'Suffolk County',
#   'phone': '(631) 582-6777',
#   'business_type': 'Dental equipment distribution and manufacturing',
#   'affected': '13',
#   'total_employees': '88',
#   'layoff_date': 'Separations',
#   'dislocation': 'Restructuring which will involve the relocation of certain dental equipment distribution and manufacturing operations to Rush, NY.',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/22/2019',
#   'reason': 'Plant Closing',
#   'company': "Ibase Operations Corp. 'dba' Qualitest",
#   'address': '111 8th Ave New York, NY 10011',
#   'county': 'New York County',
#   'phone': '(619) 278-9481',
#   'business_type': 'Independent software testing & Quality Assurance Service',
#   'affected': '63',
#   'total_employees': '63',
#   'layoff_date': 'February',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '9/23/2019',
#   'reason': 'Plant Unit Closing',
#   'company': 'ACCO Brands USA LLC',
#   'address': '941 Acco Way Ogdensburg, NY 13669',
#   'county': 'St. Lawrence County',
#   'phone': '(315) 605-3090',
#   'business_type': 'Manufacturing operations',
#   'affected': '54',
#   'total_employees': '100',
#   'layoff_date': 'Due',
#   'dislocation': 'Termination of Manufacturing Operations',
#   'union': 'United Steel, Paper and Forestry, Rubber, Manufacturing, Energy, Allied Industrial and Service Workers International Union, Local 4-503',
#   'classification': 'Plant Unit Closing'},
#  {'notice_date': '12/3/2019',
#   'reason': 'Plant Closing',
#   'company': 'Oakwood Worldwide (US) LP',
#   'address': '888 Sixth Avenue, Suite 305 New York, NY 10017',
#   'county': 'New York County',
#   'phone': '(562) 473-7383',
#   'business_type': 'Providing temporary and long-term housing accommodations for relocated individuals and corporate officials.',
#   'affected': '21',
#   'total_employees': '21',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'New York Hotel & Motel Trades Council',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/27/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Distinctive Maintenance Partners, LLC',
#   'address': '851 Tinton Avenue Bronx, NY 10456',
#   'county': 'Bronx County',
#   'phone': '(718) 764-0000',
#   'business_type': 'Cleaning Services',
#   'affected': '118',
#   'total_employees': '',
#   'layoff_date': 'December',
#   'dislocation': 'Non-renewal of service contract with Acacia Housing Network Inc.',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '11/25/2019',
#   'reason': 'Plant Unit Closing',
#   'company': 'PrimeFlight Aviation Services, Inc.',
#   'address': 'John F. Kennedy International Airport Queens, NY 11430',
#   'county': 'Queens County',
#   'phone': '(281) 942-6800',
#   'business_type': 'Provides airline, aircraft, airport services',
#   'affected': '450',
#   'total_employees': '450',
#   'layoff_date': '3/1/2020',
#   'dislocation': 'Loss of contract with JetBlue Airway Corporation at John F. Kennedy International Airport',
#   'union': 'Service Employees International Union Local 32BJ (SEIU)',
#   'classification': 'Plant Unit Closing'},
#  {'notice_date': '11/22/2019',
#   'reason': 'Plant Unit Closing',
#   'company': 'Jet.com Inc. (Walmart)',
#   'address': '1055 Bronx River Ave Bronx, NY 10472',
#   'county': 'Bronx County',
#   'phone': '(312) 513-8842',
#   'business_type': 'Online grocery services',
#   'affected': '160',
#   'total_employees': '160',
#   'layoff_date': '2/28/2020',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Unit Closing'},
#  {'notice_date': '11/22/2019',
#   'reason': 'Plant Layoff',
#   'company': 'WeWork Companies, Inc.',
#   'address': '115 W 18th St. New York, NY 10011',
#   'county': 'New York County',
#   'phone': '(646) 809-4474',
#   'business_type': 'Commercial real estate company',
#   'affected': '414',
#   'total_employees': '898',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '11/22/2019',
#   'reason': 'Plant Closing',
#   'company': 'Salisbury Hotel',
#   'address': '123 West 57th Street New York, NY 10019',
#   'county': 'New York County',
#   'phone': '(518) 740-2493',
#   'business_type': 'Hotel',
#   'affected': '87',
#   'total_employees': '87',
#   'layoff_date': '2/20/2020',
#   'dislocation': 'Economic',
#   'union': 'New York Hotel and Motel Trades Council, AFL-CIO (Local 6)',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/25/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Eastman Kodak Company (Kodak Office)',
#   'address': '343 State Street Rochester, NY 14650',
#   'county': 'Monroe County',
#   'phone': '(585) 724-6615',
#   'business_type': 'Photographic equipment and Supplies',
#   'affected': '1',
#   'total_employees': '178',
#   'layoff_date': '2/22/2020',
#   'dislocation': 'Economic',
#   'union': 'The employee is not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '7/13/2018',
#   'reason': 'Plant Closing',
#   'company': 'Gourmet Management Corp. (TGI Fridays, KFC, Taco Bell, Pizza Hut, Haagen Dazs, Tim Hortons & Beer Cart Restaurants located at the Restaurant Complex on the Amtrak level of Penn Station)',
#   'address': '560 Fifth Avenue, 3rd Floor New York, NY 10036',
#   'county': 'New York County',
#   'phone': '(212) 560-1658',
#   'business_type': 'Restaurant',
#   'affected': '45',
#   'total_employees': '45',
#   'layoff_date': 'Close',
#   'dislocation': 'Expiration of lease',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/14/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Home Box Office. Inc.',
#   'address': '30 Hudson Yards New York, NY 10001',
#   'county': 'New York County',
#   'phone': '(212) 512-5644',
#   'business_type': 'American premium channel owned by the Home Box Office, Inc.',
#   'affected': '15',
#   'total_employees': '1173',
#   'layoff_date': 'Separations',
#   'dislocation': 'Merger',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '11/15/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Residential Treatment Center and Learning Center, Lutheran  Social Services Group, Inc. (Gustavus Adoiphus Child and Family Services, Inc.)',
#   'address': '715 Falconer Avenue Jamestown, NY 14701',
#   'county': 'Chautauqua County',
#   'phone': '(716) 665-8136',
#   'business_type': 'American premium channel owned by the Home Box Office, Inc.',
#   'affected': '15',
#   'total_employees': '1173',
#   'layoff_date': 'The',
#   'dislocation': 'Merger',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '11/15/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Residential Treatment Center (Gustavus Adolphus Child and  Family Services, Inc.)',
#   'address': '200 Gustavus Avenue Jamestown, NY 14701',
#   'county': 'Chautauqua County',
#   'phone': '(716) 665-8136',
#   'business_type': 'American premium channel owned by the Home Box Office, Inc.',
#   'affected': '15',
#   'total_employees': '1173',
#   'layoff_date': 'The',
#   'dislocation': 'Merger',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/15/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Learning Center (Gustavus Adolphus Child and Family Services,  Inc.)',
#   'address': '210 Gustavus Avenue Jamestown, NY 14701',
#   'county': 'Chautauqua County',
#   'phone': '(716) 665-8136',
#   'business_type': 'American premium channel owned by the Home Box Office, Inc.',
#   'affected': '15',
#   'total_employees': '1173',
#   'layoff_date': 'Layoff',
#   'dislocation': 'Merger',
#   'union': 'New York State United Teachers',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/20/2019',
#   'reason': 'Plant Closing',
#   'company': 'Mountain States Rosen Company (Hunts Point Co Op Markets)',
#   'address': '355 Food Center Drive Bronx,  NY 10474',
#   'county': 'Bronx County',
#   'phone': '(970) 576-3600  Ext',
#   'business_type': 'American premium channel owned by the Home Box Office, Inc.',
#   'affected': '15',
#   'total_employees': '1173',
#   'layoff_date': 'Layoff',
#   'dislocation': 'Merger',
#   'union': 'UFCW Local 342',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/22/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Home Box Office, Inc.',
#   'address': '30 Hudson Yards New York, NY 10001',
#   'county': 'New York County',
#   'phone': '(212) 512-5644',
#   'business_type': 'American premium channel owned by the Home Box Office, Inc.',
#   'affected': '12',
#   'total_employees': '1173',
#   'layoff_date': 'Separations',
#   'dislocation': 'Merger',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '11/12/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Eastman Kodak Company (Kodak Office)',
#   'address': '343 State Street Rochester, NY 14650',
#   'county': 'Monroe County',
#   'phone': '(585) 724-6615',
#   'business_type': 'Photographic equipment and Supplies',
#   'affected': '1',
#   'total_employees': '',
#   'layoff_date': 'February',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '11/12/2019',
#   'reason': 'Plant Closing',
#   'company': 'Plated.',
#   'address': '111 W. 19th Street, 3rd Floor New York, NY 10011',
#   'county': 'New York County',
#   'phone': '(631) 334-1937',
#   'business_type': 'American ingredient-and-recipe meal kit service',
#   'affected': '128',
#   'total_employees': '128',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '7/31/2019',
#   'reason': 'Plant Closing',
#   'company': 'Cayuga Operating Company LLC (Heorot Power)',
#   'address': '228 Cayuga Drive Lansing, NY 14882',
#   'county': 'Tompkins County',
#   'phone': '(607) 533-7913 Ext',
#   'business_type': 'Power station',
#   'affected': '44',
#   'total_employees': '44',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'International Brotherhood of Electrical Workers, Local 10',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/8/2019',
#   'reason': 'Plant Closing',
#   'company': 'Transform SR LLC (Sears Unit #01984)',
#   'address': 'S 3701 McKinley Parkway Buffalo, NY 14219',
#   'county': 'Erie County',
#   'phone': '(847) 286-1427',
#   'business_type': 'Retail store',
#   'affected': '45',
#   'total_employees': '45',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/8/2019',
#   'reason': 'Plant Closing',
#   'company': 'Transform KM LLC (Kmart Unit #03862)',
#   'address': '5151 Sunrise Highway Bohemia, NY 11716',
#   'county': 'Suffolk County',
#   'phone': '(847) 286-1427',
#   'business_type': 'Retail store',
#   'affected': '78',
#   'total_employees': '78',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/8/2019',
#   'reason': 'Plant Closing',
#   'company': 'Transform KM LLC (Sidney - Kmart Unit #07676)',
#   'address': '171 Delaware Avenue Sidney, NY 13838',
#   'county': 'Delaware County',
#   'phone': '(847) 286-1427',
#   'business_type': 'Retail store',
#   'affected': '84',
#   'total_employees': '84',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/1/2019',
#   'reason': 'Plant Closing',
#   'company': 'Forever 21 (Store #0614)',
#   'address': 'World Trade Center 185 Greenwich Street, Ste. LL4435 New York, NY 10007',
#   'county': 'New York County',
#   'phone': '(213) 765-2966',
#   'business_type': 'Retail Store',
#   'affected': '66',
#   'total_employees': '126',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/16/2019',
#   'reason': 'Plant Closing',
#   'company': 'Barneys New York',
#   'address': '575 5th Avenue New York, NY 10017',
#   'county': 'New York County',
#   'phone': '(212) 450-8606',
#   'business_type': 'Retail',
#   'affected': '165',
#   'total_employees': '165',
#   'layoff_date': 'Employment',
#   'dislocation': 'Economic',
#   'union': 'New York New Jersey Regional Joint Board Workers United A/W SEIU',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/30/2019',
#   'reason': 'Plant Closing',
#   'company': "Damiano Corp of Jamaica d/b/a McDonald's",
#   'address': '166-30 Jamaica Ave Jamaica, NY 11432',
#   'county': 'Queens County',
#   'phone': '(201) 954-3135',
#   'business_type': 'Restaurant',
#   'affected': '23',
#   'total_employees': '23',
#   'layoff_date': 'November',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/5/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Marvell Semiconductor, Inc. (East Fishkill office)',
#   'address': '2070 Route 52 Hopewell Junction, NY 12533',
#   'county': 'Dutchess County',
#   'phone': '(408) 222-2500',
#   'business_type': 'Global semiconductor company',
#   'affected': '23',
#   'total_employees': '',
#   'layoff_date': 'January',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '11/7/2019',
#   'reason': 'Plant Layoff',
#   'company': 'LSC Communications US, LLC (Dover Publications office)',
#   'address': '31 East 2nd Street Mineola, NY 11501',
#   'county': 'Nassau County',
#   'phone': '(516) 294-7000 Ext',
#   'business_type': 'Commercial printing company',
#   'affected': '23',
#   'total_employees': '59',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/29/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Eastman Kodak Company (Kodak Office)',
#   'address': '343 State Street Rochester, NY 14650',
#   'county': 'Monroe County',
#   'phone': '(585) 724-6615',
#   'business_type': 'Photographic equipment and Supplies',
#   'affected': '1',
#   'total_employees': '',
#   'layoff_date': '1/26/2020',
#   'dislocation': 'Economic',
#   'union': 'The employee is not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/30/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Eastman Kodak Company (Kodak Office)',
#   'address': '343 State Street Rochester, NY 14650',
#   'county': 'Monroe County',
#   'phone': '(585) 724-6615',
#   'business_type': 'Photographic equipment and Supplies',
#   'affected': '3',
#   'total_employees': '',
#   'layoff_date': '1/27/2020',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/31/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Eastman Kodak Company (Kodak Office)',
#   'address': '343 State Street Rochester, NY 14650',
#   'county': 'Monroe County',
#   'phone': '(585) 724-6615',
#   'business_type': 'Photographic equipment and Supplies',
#   'affected': '2',
#   'total_employees': '',
#   'layoff_date': '1/28/2020',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/28/2019',
#   'reason': 'Plant Layoff',
#   'company': 'L3Harris Technologies',
#   'address': '600 Third Avenue New York, NY 10016',
#   'county': 'New York County',
#   'phone': '(212) 805-5318',
#   'business_type': 'A global defense technology leader',
#   'affected': '34',
#   'total_employees': '',
#   'layoff_date': 'January',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/31/2019',
#   'reason': 'Plant Layoff',
#   'company': 'IPRO Headquarters',
#   'address': '1979 Marcus Avenue, Suite 105 Lake Success, New York 11042',
#   'county': 'Nassau County',
#   'phone': '(516) 209-5425',
#   'business_type': 'Health Care Service Contracts',
#   'affected': '136',
#   'total_employees': '228',
#   'layoff_date': 'The',
#   'dislocation': 'End of one of IPRO’s core contracts',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/31/2019',
#   'reason': 'Plant Closing',
#   'company': 'Lord + Taylor',
#   'address': '1825 Palisades Center Drive West Nyack, NY 10994',
#   'county': 'Rockland County',
#   'phone': '(860) 626-9652',
#   'business_type': 'Retail store',
#   'affected': '91',
#   'total_employees': '91',
#   'layoff_date': 'Employee',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/28/2019',
#   'reason': 'Plant Unit Closing',
#   'company': 'Bethany Nursing Home & HRF, Inc. and Bethany Retirement Home, Inc.',
#   'address': '(collectively Bethany Village) 3005 Watkins Road Horseheads, NY 14845',
#   'county': 'Chemung County',
#   'phone': '(607) 378-6954',
#   'business_type': 'Food service operations unit',
#   'affected': '52',
#   'total_employees': '52',
#   'layoff_date': '2/8/2020',
#   'dislocation': 'Bethany Village will be contracting with Morrison Community Living, a division of Morrison Management Specialists, Inc.',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Unit Closing (ending its food service operations)'},
#  {'notice_date': '9/3/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Dexia Credit Local, New York Branch',
#   'address': '445 Park Avenue New York, NY 10022',
#   'county': 'New York County',
#   'phone': '(212) 705-0725',
#   'business_type': 'Bank',
#   'affected': '33',
#   'total_employees': '71',
#   'layoff_date': 'Employee',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/23/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Eastman Kodak Company (Kodak Office)',
#   'address': '343 State Street Rochester, NY 14650',
#   'county': 'Monroe County',
#   'phone': '(585) 724-6615',
#   'business_type': 'Photographic equipment and Supplies',
#   'affected': '2',
#   'total_employees': '',
#   'layoff_date': 'January',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/29/2019',
#   'reason': 'Plant Closing',
#   'company': 'iPic Entertainment Inc.',
#   'address': '1 Hamilton Street Dobbs Ferry, NY 10522',
#   'county': 'Westchester County',
#   'phone': '(561) 886-3236',
#   'business_type': 'Theater company',
#   'affected': '126',
#   'total_employees': '126',
#   'layoff_date': 'November',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/29/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Macquarie Holdings (U.S.A.) Inc.',
#   'address': '125 W. 55th Street New York, NY 10019',
#   'county': 'New York County',
#   'phone': '(212) 231-1916',
#   'business_type': 'Fincanial services (US Cash Equities Division)',
#   'affected': '86',
#   'total_employees': '',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/29/2019',
#   'reason': 'Plant Closing',
#   'company': 'Cascades Tissue Group',
#   'address': '148 Hudson River Road Waterford, NY 12188',
#   'county': 'Saratoga County',
#   'phone': '(518) 238-1900 Ext',
#   'business_type': 'Tissue manufacturing and conversion company',
#   'affected': '96',
#   'total_employees': '96',
#   'layoff_date': '3/27/2020',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/24/2019',
#   'reason': 'Plant Layoff',
#   'company': 'CONMED Corporation and Buffalo Filter, LLC',
#   'address': '5900 Genesee Street Lancaster, NY 14086',
#   'county': 'Erie County',
#   'phone': '(201) 419-9246',
#   'business_type': 'Medical equipment manufacturer',
#   'affected': '54',
#   'total_employees': '96',
#   'layoff_date': 'February',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/9/2019',
#   'reason': 'Plant Closing',
#   'company': 'HMS Ferries, Inc. (HMS Global Maritime LLC)',
#   'address': '10 South Street New York, NY 10004',
#   'county': 'New York County',
#   'phone': '(812) 941-9990',
#   'business_type': 'Full-service marine management company',
#   'affected': '29',
#   'total_employees': '29',
#   'layoff_date': '10/31/2019',
#   'dislocation': 'Loss of contract to continue services at the Governors Island site',
#   'union': 'International Organization of Masters, Mates & Pilots',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/25/2019',
#   'reason': 'Plant Closing',
#   'company': 'Nordstrom (Rack Store at Skyview Center (Store 512)',
#   'address': '4024 College Point Blvd., Suite D417 Flushing, NY 11354',
#   'county': 'Queens County',
#   'phone': '(206) 303-2756',
#   'business_type': 'Retail Store',
#   'affected': '42',
#   'total_employees': '42',
#   'layoff_date': 'The',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/23/2019',
#   'reason': 'Plant Layoff',
#   'company': 'AmTrust Financial Services, Inc.',
#   'address': '600 Essjay Drive Williamsville, NY 14221',
#   'county': 'Erie County',
#   'phone': '(216) 727-4798',
#   'business_type': 'Insurance',
#   'affected': '39',
#   'total_employees': '74',
#   'layoff_date': 'The',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '8/1/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Home Box Office, Inc.',
#   'address': '300 New Highway Hauppauge, NY 11778',
#   'county': 'Suffolk County',
#   'phone': '(212) 512-8684',
#   'business_type': 'American premium channel',
#   'affected': '64',
#   'total_employees': '157',
#   'layoff_date': 'Four',
#   'dislocation': 'Merger',
#   'union': 'Radio and Television Broadcast Engineers Union Local 1212 (IBEW)',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '8/1/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Home Box Office. Inc.',
#   'address': '300 New Highway Hauppauge, NY 11778',
#   'county': 'Suffolk County',
#   'phone': '(212) 512-8684',
#   'business_type': 'American premium channel',
#   'affected': '64',
#   'total_employees': '157',
#   'layoff_date': 'Separations',
#   'dislocation': 'Merger',
#   'union': 'Radio and Television Broadcast Engineers Union Local 1212 (IBEW)',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/16/2019',
#   'reason': 'Plant Closing',
#   'company': 'Barneys New York',
#   'address': '575 5th Avenue New York, NY 10017',
#   'county': 'New York County',
#   'phone': '(212) 450-8606',
#   'business_type': 'Retail',
#   'affected': '165',
#   'total_employees': '165',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'New York New Jersey Regional Joint Board Workers United A/W SEIU',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/9/2019',
#   'reason': 'Plant Closing',
#   'company': "Del Frisco's Grille",
#   'address': '160 Walt Whitman Road, Suite 1108B Huntington Station, NY 11746',
#   'county': 'Suffolk County',
#   'phone': '(469) 913-1863',
#   'business_type': 'Full service restaurant',
#   'affected': '72',
#   'total_employees': '72',
#   'layoff_date': '12/23/2019',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/17/2019',
#   'reason': 'Plant Closing',
#   'company': 'Premier Paratransit LLC',
#   'address': '940 Remsen Avenue Brooklyn, NY 11236',
#   'county': 'Brooklyn County',
#   'phone': '(718) 927-1410 Ext',
#   'business_type': 'Full service transportation business geared towards the physically challenged.',
#   'affected': '303',
#   'total_employees': '303',
#   'layoff_date': 'Affected',
#   'dislocation': 'Loss of contract with the New York City Transit Authority',
#   'union': 'Local 713 International Brotherhood of Trade Unions',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/17/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Cartoon Network Enterprises',
#   'address': '30 Hudson Yards New York, NY 10001',
#   'county': 'New York County',
#   'phone': '(404) 575-9735',
#   'business_type': 'Media services',
#   'affected': '7',
#   'total_employees': '12',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/16/2019',
#   'reason': 'Plant Unit Closing',
#   'company': 'EmblemHealth Services Company, LLC',
#   'address': '55 Water St. New York, NY 10041',
#   'county': 'New York County',
#   'phone': '(646) 447-0495',
#   'business_type': 'Health claims processing',
#   'affected': '60',
#   'total_employees': '1241',
#   'layoff_date': 'Separations',
#   'dislocation': 'Relocation of claims processing work',
#   'union': 'Local 153 Office & Professional Employees International Union',
#   'classification': 'Plant Unit Closing'},
#  {'notice_date': '10/15/2019',
#   'reason': 'Plant Layoff',
#   'company': 'ER Select LLC at St. James Mercy Hospital',
#   'address': '411 Canisteo Street Hornell, NY 14843',
#   'county': 'Steuben County',
#   'phone': '(585) 420-3914',
#   'business_type': 'Professional Employer Organization',
#   'affected': '352',
#   'total_employees': '352',
#   'layoff_date': '12/31/2019',
#   'dislocation': 'Termination of contract with St. James Mercy Hospital.',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '6/28/2019',
#   'reason': 'Plant Closing',
#   'company': 'DHR Restaurant Co. LLC, aka Rare Bar & Grill Murray Hill',
#   'address': '303 Lexington Avenue New York, NY 10016',
#   'county': 'New York County',
#   'phone': '(646) 401-4727',
#   'business_type': 'Restaurant',
#   'affected': '47',
#   'total_employees': '47',
#   'layoff_date': '2/29/2020',
#   'dislocation': 'Seasonal venue',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '9/23/2019',
#   'reason': 'Plant Unit Closing',
#   'company': 'ACCO Brands USA LLC',
#   'address': '941 Acco Way Ogdensburg, NY 13669',
#   'county': 'St. Lawrence County',
#   'phone': '(315) 605-3090',
#   'business_type': 'Manufacturing operations',
#   'affected': '62',
#   'total_employees': '106',
#   'layoff_date': 'Separations',
#   'dislocation': 'Termination of Manufacturing Operations',
#   'union': 'United Steel, Paper and Forestry, Rubber, Manufacturing, Energy, Allied Industrial and Service Workers International Union, Local 4-503',
#   'classification': 'Plant Unit Closing'},
#  {'notice_date': '10/16/2019',
#   'reason': 'Plant Closing',
#   'company': 'Barneys New York',
#   'address': '575 5th Avenue New York, NY 10017',
#   'county': 'New York County',
#   'phone': '(212) 450-8606',
#   'business_type': 'Retail',
#   'affected': '785',
#   'total_employees': '785',
#   'layoff_date': '11/1/2019',
#   'dislocation': 'Economic',
#   'union': 'New York New Jersey Regional Joint Board Workers UnitedA/W SEIU',
#   'classification': 'Plant Closing'},
#  {'notice_date': '9/20/2019',
#   'reason': 'Plant Layoff',
#   'company': 'PRWT Services, Inc.',
#   'address': '1150 South Avenue Staten Island, NY 10314',
#   'county': 'Richmond County',
#   'phone': '(215) 569-8810 Ext',
#   'business_type': 'Data Processing Services',
#   'affected': '117',
#   'total_employees': '117',
#   'layoff_date': '12/20/2019',
#   'dislocation': 'Contracted work is being relocated by contracting entity',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/2/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Home Box Office. Inc. (HBO Service Corp.)',
#   'address': '30 Hudson Yards New York, NY 10001',
#   'county': 'New York County',
#   'phone': '(212) 512-7699',
#   'business_type': 'American premium channel',
#   'affected': '32',
#   'total_employees': '1176',
#   'layoff_date': 'Separations',
#   'dislocation': 'Merger',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/8/2019',
#   'reason': 'Plant Closing',
#   'company': 'Port Morris Tile & Marble LP',
#   'address': '460 West 34th Street, Ste1700 New York, NY 10001',
#   'county': 'New York County',
#   'phone': '(718) 378-6100',
#   'business_type': 'Tile and terrazzo contactors',
#   'affected': '189',
#   'total_employees': '215',
#   'layoff_date': 'January',
#   'dislocation': 'Economic',
#   'union': 'BAC Local 7 and International Brotherhood of Teamsters Local 282',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/8/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Eastman Kodak Company (Kodak Office)',
#   'address': '343 State Street Rochester, NY 14650',
#   'county': 'Monroe County',
#   'phone': '(585) 724-6615',
#   'business_type': 'Photographic equipment and Supplies',
#   'affected': '1',
#   'total_employees': '',
#   'layoff_date': '1/6/2020',
#   'dislocation': 'Economic',
#   'union': 'The employee is not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '8/06/2019',
#   'reason': 'Plant Closing',
#   'company': 'Transform KM LLC (Kmart Store 04726)',
#   'address': '975 Fairmount Ave W E Jamestown, NY 14701',
#   'county': 'Chautauqua County',
#   'phone': '(847) 286-1427',
#   'business_type': 'Retail store',
#   'affected': '35',
#   'total_employees': '35',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/7/2019',
#   'reason': 'Plant Closing',
#   'company': 'Somos Healthcare Providers, Inc.',
#   'address': '519 Eighth Avenue, 14th Floor New York, NY 10118',
#   'county': 'New York County',
#   'phone': '(516) 642-4068',
#   'business_type': 'Community care and advocate community provider',
#   'affected': '130',
#   'total_employees': '130',
#   'layoff_date': 'Separations',
#   'dislocation': 'New York State contract expired',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/3/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Eastman Kodak Company',
#   'address': '(Kodak Office) 343 State Street Rochester, NY 14650',
#   'county': 'Monroe County',
#   'phone': '(585) 724-6615',
#   'business_type': 'Photographic equipment and Supplies',
#   'affected': '1',
#   'total_employees': '',
#   'layoff_date': '12/31/2019',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/8/2019',
#   'reason': 'Plant Layoff',
#   'company': 'CONMED Corporation and Buffalo Filter, LLC',
#   'address': '5900 Genesee Street Lancaster, NY 14086',
#   'county': 'Erie County',
#   'phone': '(574) 306-8710',
#   'business_type': 'Medical equipment manufacturer',
#   'affected': '6',
#   'total_employees': '96',
#   'layoff_date': 'January',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '10/7/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Bonobos, Inc., a subsidiary of Walmart, Inc.',
#   'address': '45 West 25th Street, 3rd Floor New York, NY 10110',
#   'county': 'New York County',
#   'phone': '(646) 532-5800',
#   'business_type': "An e-commerce-driven apparel subsidiary of Walmart headquartered in New York City that designs and sells men's clothing.",
#   'affected': '26',
#   'total_employees': '220',
#   'layoff_date': '1/17/2020',
#   'dislocation': 'Changes to its organizational structure',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '8/21/2019',
#   'reason': 'Plant Closing',
#   'company': 'Library Bar (at Hudson Hotel)',
#   'address': '358 West 58th St. New York, NY 10019',
#   'county': 'New York County',
#   'phone': '(212) 453-6400',
#   'business_type': 'Bar in the Hudson Hotel',
#   'affected': '13',
#   'total_employees': '13',
#   'layoff_date': '11/3/2019',
#   'dislocation': 'Economic',
#   'union': 'New York Hotel & Motel Trades Council, AFL-CIO, affiliated with UNITE HERE, Local 6',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/4/2019',
#   'reason': 'Plant Closing',
#   'company': 'J & M Distributing Co., Inc. (Certo Brothers Distributing)',
#   'address': '2500 North America Drive West Seneca, NY 14224',
#   'county': 'Erie County',
#   'phone': '(716) 827-1133 Ext',
#   'business_type': 'Beer and Ale Merchant Wholesalers',
#   'affected': '270',
#   'total_employees': '270',
#   'layoff_date': 'The',
#   'dislocation': 'Economic',
#   'union': 'Teamsters Local 264, I.B.T.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/3/2019',
#   'reason': 'Plant Closing',
#   'company': 'RAROC, Inc. a subsidiary of Patina Restaurant Group, LLC',
#   'address': '45 Rockefeller Plaza New York, NY 10111',
#   'county': 'New York County',
#   'phone': '(347) 491-9358',
#   'business_type': 'Restaurant and Entertainment',
#   'affected': '328',
#   'total_employees': '328',
#   'layoff_date': 'The',
#   'dislocation': 'Lease termination',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/4/2019',
#   'reason': 'Plant Closing',
#   'company': "Taft Food Court, LLC - Restaurant Complex - Food Court (Pizza Hut, Nathan's and KFC) and Tad's Steaks Restaurants",
#   'address': '761 Seventh Ave New York, NY 10019',
#   'county': 'New York County',
#   'phone': '(212) 560-1749',
#   'business_type': 'Restaurant',
#   'affected': '41',
#   'total_employees': '41',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': "Tad's Steaks are represented by the UNITE HERE Local 100",
#   'classification': 'Plant Closing'},
#  {'notice_date': '10/4/2019',
# ...
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/31/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Eastman Kodak Company (Eastman Business Park)',
#   'address': '1669 Lake Avenue Rochester, NY 14650',
#   'county': 'Monroe County',
#   'phone': '(585) 724-6615',
#   'business_type': 'Photographic equipment and Supplies',
#   'affected': '2',
#   'total_employees': '',
#   'layoff_date': '4/30/2019',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '1/28/2019',
#   'reason': 'Plant Closing',
#   'company': 'ABM Aviation Inc.',
#   'address': 'Delta Airlines at JFK International Airport. Terminals 2 and 4 Jamaica, NY 11430',
#   'county': 'Queens County',
#   'phone': '(718) 917-2079',
#   'business_type': 'Cabin cleaning services at Delta Airlines at JFK International Airport. Terminals 2 and 4',
#   'affected': '528',
#   'total_employees': '528',
#   'layoff_date': '5/3/2019',
#   'dislocation': 'Contractual Loss',
#   'union': 'SEIU Local 32BJ',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/29/2019',
#   'reason': 'Plant Unit Closing',
#   'company': 'Concentrix CVG Corporation',
#   'address': '(Formerly Convergys Corporation) 146 Arsenal Street Watertown, NY 13601',
#   'county': 'Jefferson County',
#   'phone': '(513) 592-6050',
#   'business_type': 'Cabin cleaning services at Delta Airlines at JFK International Airport. Terminals 2 and 4',
#   'affected': '528',
#   'total_employees': '528',
#   'layoff_date': '5/3/2019',
#   'dislocation': 'Contractual Loss',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Unit  Closing'},
#  {'notice_date': '1/18/2019',
#   'reason': 'Plant Closings',
#   'company': 'Petland Discounts Inc.',
#   'address': 'Various Locations',
#   'county': 'Nassau, Suffolk County',
#   'phone': '(631) 521-8326',
#   'business_type': 'Retail pet store',
#   'affected': '367',
#   'total_employees': '367',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closings'},
#  {'notice_date': '1/15/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Metropolitan Jewish Home Care, Inc. d\\b\\a MJHS Home Care',
#   'address': '6323 Seventh Avenue Brooklyn, NY 11220',
#   'county': 'Kings County',
#   'phone': '(718) 491-7290',
#   'business_type': 'Home care services',
#   'affected': '112',
#   'total_employees': '246',
#   'layoff_date': 'April',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '1/17/2019',
#   'reason': 'Plant Closing',
#   'company': 'Centerplate at the New York Racing Association (NYRA)',
#   'address': 'Saratoga Racetracks 267 Union Avenue Saratoga Springs, NY 12866',
#   'county': 'Saratoga County',
#   'phone': '(864) 248-2042',
#   'business_type': 'Hospitality services',
#   'affected': '441',
#   'total_employees': '441',
#   'layoff_date': 'The',
#   'dislocation': 'Contract Loss',
#   'union': 'New York Hotel & Motel Trades Council, AFL-CIO',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/25/2019',
#   'reason': 'Plant Layoff',
#   'company': 'SAE Sun and Earth Energy Inc.',
#   'address': '444 Washington Street Rensselaer, NY 12144',
#   'county': 'Rensselaer County',
#   'phone': '(518) 444-2044',
#   'business_type': 'Hospitality services',
#   'affected': '441',
#   'total_employees': '441',
#   'layoff_date': 'The',
#   'dislocation': 'Contract Loss',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '1/25/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Monolith Solar Associates, LLC',
#   'address': '444 Washington Street Rensselaer, NY 12144',
#   'county': 'Rensselaer County',
#   'phone': '(518) 444-2044',
#   'business_type': 'Hospitality services',
#   'affected': '441',
#   'total_employees': '441',
#   'layoff_date': 'The',
#   'dislocation': 'Contract Loss',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '1/25/2019',
#   'reason': 'Plant Layoff',
#   'company': 'Monticello Raceway Management, Inc. (Casino)',
#   'address': '204 State Route 17B Monticello, NY 12701',
#   'county': 'Sullivan County',
#   'phone': '(845) 428-7200 Ext. 1460',
#   'business_type': 'Hospitality services',
#   'affected': '441',
#   'total_employees': '441',
#   'layoff_date': 'The',
#   'dislocation': 'Contract Loss',
#   'union': "New York Hotel & Motel Trades Council,  AFL-CIO - 92 employees; the Laborers' International Union of North America,  Local 17, AFL-CIO- 13 employees; the International Union of Operating  Engineers, Local 825 – 5 employees; and the Northeast Regional Council of  Carpenters, United Brotherhood of Carpenters and Joinders of America- 2  employees.",
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/17/2018',
#   'reason': 'Plant Closing',
#   'company': 'Celmatix Inc. (Operations Office)',
#   'address': '14 Wall Street New York, NY 10005',
#   'county': 'New York County',
#   'phone': '(917) 371-2506',
#   'business_type': 'Biotechnology company',
#   'affected': '66',
#   'total_employees': '66',
#   'layoff_date': 'Employment',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '7/13/2018',
#   'reason': 'Plant Closing',
#   'company': 'Gourmet Management Corp. (TGI Fridays, KFC, Taco Bell, Pizza Hut, Haagen Dazs, Tim Hortons & Beer Cart Restaurants located at the Restaurant Complex on the Amtrak level of Penn Station)',
#   'address': '560 Fifth Avenue, 3rd Floor New York, NY 10036',
#   'county': 'New York County',
#   'phone': '(212) 560-1658',
#   'business_type': 'Restaurant',
#   'affected': '86',
#   'total_employees': '86',
#   'layoff_date': 'Layoffs',
#   'dislocation': 'Expiration of lease',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/18/2019',
#   'reason': 'Plant Closing',
#   'company': 'Third & 50, LLC (aka Dos Caminos)',
#   'address': '825 Third Avenue New York, NY 10022',
#   'county': 'New York County',
#   'phone': '(718) 386-7187',
#   'business_type': 'Restaurant',
#   'affected': '100',
#   'total_employees': '100',
#   'layoff_date': 'Separation',
#   'dislocation': 'Lease expiration',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/18/2019',
#   'reason': 'Plant Closing',
#   'company': 'Mercedes Distribution Center, Inc.',
#   'address': '63 Flushing Avenue, Unit 340 Brooklyn, NY 11205',
#   'county': 'Kings County',
#   'phone': '(718) 534-3003',
#   'business_type': 'Warehouse Distribution service',
#   'affected': '100',
#   'total_employees': '100',
#   'layoff_date': 'The',
#   'dislocation': 'Economic',
#   'union': 'International Brotherhood of Teamsters, Local 553',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/18/2019',
#   'reason': 'Plant Closing',
#   'company': "Macy's",
#   'address': '7000 Fashion Drive Nanuet, NY 10954',
#   'county': 'Rockland County',
#   'phone': '(646) 787-4816',
#   'business_type': 'Retail Store',
#   'affected': '92',
#   'total_employees': '92',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/16/2019',
#   'reason': 'Plant Layoff',
#   'company': 'TheaterMania.com',
#   'address': '550 7th Ave New York, NY 10018',
#   'county': 'New York County',
#   'phone': '(416)-687-2062',
#   'business_type': 'Offers directory of shows, tickets, and discounts across the U.S.',
#   'affected': '17',
#   'total_employees': '81',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '1/7/2018',
#   'reason': 'Plant Layoff',
#   'company': 'Senior Rehab Solutions (Norwegian Home and Health Center)',
#   'address': '1250 67th Street Brooklyn, NY 11219',
#   'county': 'Kings County',
#   'phone': '(214) 252-7653',
#   'business_type': 'Nursing home',
#   'affected': '22',
#   'total_employees': '22',
#   'layoff_date': 'The',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Layoff'},
#  {'notice_date': '1/16/2019',
#   'reason': 'Plant Closing',
#   'company': 'CareConnect Insurance Company, Inc.',
#   'address': '2200 Northern Boulevard East Hills, NY 11548',
#   'county': 'Nassau County',
#   'phone': '(516) 405-7925',
#   'business_type': 'Health insurance market',
#   'affected': '46',
#   'total_employees': '40',
#   'layoff_date': 'Phase',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/10/2019',
#   'reason': 'Plant Closing',
#   'company': "Kohl's Department Stores, Inc. (Store #1328)",
#   'address': '6135 Junction Blvd. Rego Park, NY 11374',
#   'county': 'Queens County',
#   'phone': '(262) 703-7000',
#   'business_type': 'Retail store',
#   'affected': '107',
#   'total_employees': '107',
#   'layoff_date': '4/13/2019',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '11/13/2018',
#   'reason': 'Plant Closing',
#   'company': 'Thomson Reuters Corporation',
#   'address': '(Operations and Enablement - Technology, Content Operations & Legal Editorial) 50 East Broad Street Rochester, NY 14614',
#   'county': 'Monroe County',
#   'phone': '(651) 848-3154',
#   'business_type': 'Multinational mass media and information firm',
#   'affected': '207',
#   'total_employees': '327',
#   'layoff_date': 'Layoffs',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/15/2019',
#   'reason': 'Plant Closing',
#   'company': 'General Motors LLC (Cadillac New York Headquarters)',
#   'address': '330 Hudson Street New York, NY 10013',
#   'county': 'New York County',
#   'phone': '(313) 407-9929',
#   'business_type': 'Automobile manufacturer and retailer.',
#   'affected': '97',
#   'total_employees': '97',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/11/2019',
#   'reason': 'Plant Closing',
#   'company': 'Calvin Klein, Inc.',
#   'address': '(Madison Collection Store) 654 Madison Avenue New York, NY 10065',
#   'county': 'New York County',
#   'phone': '(212) 292-9785',
#   'business_type': 'Clothing Retail store',
#   'affected': '29',
#   'total_employees': '29',
#   'layoff_date': 'Three',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/10/2019',
#   'reason': 'Plant Closing',
#   'company': 'Aveda Institute Inc.',
#   'address': '(Aveda Institute New York School) 233 Spring Street New York, NY 10013',
#   'county': 'New York County',
#   'phone': '(212) 230-6181',
#   'business_type': 'Beauty school',
#   'affected': '48',
#   'total_employees': '48',
#   'layoff_date': 'Separations',
#   'dislocation': 'Sale of the Aveda Institute New York School',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/7/2019',
#   'reason': 'Plant Closing',
#   'company': 'Independence Care System, Inc. (ICS)',
#   'address': '257 Park Avenue South New York, NY 10010',
#   'county': 'New York County',
#   'phone': '(212) 584-2580',
#   'business_type': 'Managed Long-Term Care (MLTC)',
#   'affected': '97',
#   'total_employees': '97',
#   'layoff_date': '4/7/2019',
#   'dislocation': 'Due to changes in its business, ICS will be closing its MLTC line of business.',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/9/2019',
#   'reason': 'Plant Closing',
#   'company': 'Pfizer, Inc.',
#   'address': '64 Maple Street Rouses Point, NY 12979',
#   'county': 'Clinton County',
#   'phone': '(212) 733-2110',
#   'business_type': 'Pharmaceuticals (production)',
#   'affected': '6',
#   'total_employees': '12',
#   'layoff_date': 'Separations',
#   'dislocation': 'Economic',
#   'union': 'International Chemical Workers Union/UFCW Local 95c',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/7/2019',
#   'reason': 'Plant Closing',
#   'company': 'AT&T Services, Inc.',
#   'address': '(Billing Inquiry Call Center Operations) 250 South Clinton Street Syracuse, NY 13202',
#   'county': 'Onondaga County',
#   'phone': '(313) 421-9648',
#   'business_type': 'Telecommunications (Billing Inquiry Call Center Operations)',
#   'affected': '155',
#   'total_employees': '155',
#   'layoff_date': '4/12/2019',
#   'dislocation': 'Transfer of operations to Orange Park, Florida',
#   'union': 'Communications Workers of America',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/7/2019',
#   'reason': 'Plant Closing',
#   'company': 'Lighthouse Management Services, LLC',
#   'address': '300 Clinton Square Rochester, NY 14604',
#   'county': 'Monroe County',
#   'phone': '(585) 246-4151',
#   'business_type': 'Property management company',
#   'affected': '48',
#   'total_employees': '48',
#   'layoff_date': 'Layoffs',
#   'dislocation': 'Termination of property management contracts',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '1/6/2019',
#   'reason': 'Plant Closing',
#   'company': 'Morrison Healthcare Food and Nutrition Services at Erie Medical Center',
#   'address': '462 Grider Street Buffalo, NY 14215',
#   'county': 'Erie County',
#   'phone': '(914) 426-8240',
#   'business_type': 'National food and nutrition services company',
#   'affected': '172',
#   'total_employees': '172',
#   'layoff_date': '4/6/2019',
#   'dislocation': 'Contractual Loss',
#   'union': 'CSEA Local 1000, AFSCME, AFL-CIO',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/27/2018',
#   'reason': 'Plant Closing',
#   'company': 'Kmart Store (Unit 07677)',
#   'address': '121 Bolivar Road Wellsville, NY 14895',
#   'county': 'Allegany County',
#   'phone': '(847) 286-1427',
#   'business_type': 'Retail Store',
#   'affected': '88',
#   'total_employees': '88',
#   'layoff_date': 'Employment',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/27/2018',
#   'reason': 'Plant Closing',
#   'company': 'Kmart Store (Unit 04928)',
#   'address': '49 Dix Avenue Ext. Queensbury, NY 12804',
#   'county': 'Warren County',
#   'phone': '(847) 286-1427',
#   'business_type': 'Retail Store',
#   'affected': '60',
#   'total_employees': '60',
#   'layoff_date': 'Employment',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/27/2018',
#   'reason': 'Plant Closing',
#   'company': 'Sears, Roebuck and Co. Full Line Store (Unit 01894)',
#   'address': '10 Miracle Mile Dr. Rochester, NY 14623',
#   'county': 'Monroe County',
#   'phone': '(847) 286-1427',
#   'business_type': 'Retail Store',
#   'affected': '70',
#   'total_employees': '70',
#   'layoff_date': 'Employment',
#   'dislocation': 'Economic',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'},
#  {'notice_date': '12/28/2018',
#   'reason': 'Plant Closing',
#   'company': 'St. Lawrence Health Alliance, Inc.',
#   'address': '3 Lyon Place Ogdensburg, NY 13669',
#   'county': 'St. Lawrence County',
#   'phone': '(315) 713-6612',
#   'business_type': 'Healthcare Services',
#   'affected': '72',
#   'total_employees': '72',
#   'layoff_date': '3/31/2019',
#   'dislocation': 'The Claxton-Hepburn Medical Center will assume operations and all employees will be offered employment.',
#   'union': 'The employees are not represented by a union.',
#   'classification': 'Plant Closing'}]

# %%
df = pd.DataFrame.from_dict(results)

# %%
df
# Out:
#     notice_date              reason  \
# 0    12/24/2019        Plant Layoff
# 1    10/16/2019       Plant Closing
# 2     9/18/2019       Plant Closing
# 3     10/7/2019       Plant Closing
# 4    12/20/2019  Plant Unit Closing
# ..          ...                 ...
# 341    1/6/2019       Plant Closing
# 342  12/27/2018       Plant Closing
# 343  12/27/2018       Plant Closing
# 344  12/27/2018       Plant Closing
# 345  12/28/2018       Plant Closing
#
#                                                company  \
# 0    Timeless Décor, LLC (LCO Destiny DBA Timeless ...
# 1                                     Barneys New York
# 2    General Parts Distribution, LLC d/b/a Carquest...
# 3                     Somos Healthcare Providers, Inc.
# 4    Regeneron Healthcare Solutions, Inc., a wholly...
# ..                                                 ...
# 341  Morrison Healthcare Food and Nutrition Service...
# 342                           Kmart Store (Unit 07677)
# 343                           Kmart Store (Unit 04928)
# 344  Sears, Roebuck and Co. Full Line Store (Unit 0...
# 345                 St. Lawrence Health Alliance, Inc.
#
#                                               address               county  \
# 0               22419 Fisher Road Watertown, NY 13601     Jefferson County
# 1                   575 5th Avenue New York, NY 10017      New York County
# 2            215 Business Park Drive Armonk, NY 10504   Westchester County
# 3    519 Eighth Avenue, 14th Floor New York, NY 10118      New York County
# 4              1 Rockwood Rd. Sleepy Hollow, NY 10591   Westchester County
# ..                                                ...                  ...
# 341               462 Grider Street Buffalo, NY 14215          Erie County
# 342             121 Bolivar Road Wellsville, NY 14895      Allegany County
# 343           49 Dix Avenue Ext. Queensbury, NY 12804        Warren County
# 344           10 Miracle Mile Dr. Rochester, NY 14623        Monroe County
# 345                 3 Lyon Place Ogdensburg, NY 13669  St. Lawrence County
#
#               phone                                   business_type affected  \
# 0    (315) 782-5759                    A supplier of Picture Frames       45
# 1    (212) 450-8606                                          Retail      165
# 2    (860) 375-1514                         Auto parts distribution       80
# 3    (516) 642-4068  Community care and advocate community provider      130
# 4    (914) 847-7128                           Biotechnology company       15
# ..              ...                                             ...      ...
# 341  (914) 426-8240    National food and nutrition services company      172
# 342  (847) 286-1427                                    Retail Store       88
# 343  (847) 286-1427                                    Retail Store       60
# 344  (847) 286-1427                                    Retail Store       70
# 345  (315) 713-6612                             Healthcare Services       72
#
#     total_employees  layoff_date  \
# 0                81          The
# 1               165   Employment
# 2                80           Of
# 3               130  Separations
# 4                      2/18/2020
# ..              ...          ...
# 341             172     4/6/2019
# 342              88   Employment
# 343              60   Employment
# 344              70   Employment
# 345              72    3/31/2019
#
#                                            dislocation  \
# 0                                             Economic
# 1                                             Economic
# 2                                             Economic
# 3                      New York State contract expired
# 4    Termination of all field and supporting staff ...
# ..                                                 ...
# 341                                   Contractual Loss
# 342                                           Economic
# 343                                           Economic
# 344                                           Economic
# 345  The Claxton-Hepburn Medical Center will assume...
#
#                                                  union      classification
# 0        The employees are not represented by a union.        Plant layoff
# 1    New York New Jersey Regional Joint Board Worke...       Plant Closing
# 2                                  Teamsters Local 202       Plant Closing
# 3        The employees are not represented by a union.       Plant Closing
# 4        The employees are not represented by a union.  Plant Unit Closing
# ..                                                 ...                 ...
# 341                   CSEA Local 1000, AFSCME, AFL-CIO       Plant Closing
# 342      The employees are not represented by a union.       Plant Closing
# 343      The employees are not represented by a union.       Plant Closing
# 344      The employees are not represented by a union.       Plant Closing
# 345      The employees are not represented by a union.       Plant Closing
#
# [346 rows x 13 columns]
